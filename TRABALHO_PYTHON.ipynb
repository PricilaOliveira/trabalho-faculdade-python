# %% [markdown]
# <a href="https://colab.research.google.com/github/PricilaOliveira/trabalho-faculdade-python/blob/main/TRABALHO_PYTHON.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
import seaborn as sb
import pandas as pd

# %%
dados_item2 = dados.loc['SKY'];

# %%
url = 'http://archive.ics.uci.edu/ml/machine-learning-databases/image/segmentation.data';
dados = pd.read_csv(url, header=2, skip_blank_lines=True);
display(dados);
# Out:
#            REGION-CENTROID-COL  REGION-CENTROID-ROW  REGION-PIXEL-COUNT  \
# BRICKFACE                140.0                125.0                   9
# BRICKFACE                188.0                133.0                   9
# BRICKFACE                105.0                139.0                   9
# BRICKFACE                 34.0                137.0                   9
# BRICKFACE                 39.0                111.0                   9
# ...                        ...                  ...                 ...
# GRASS                     36.0                243.0                   9
# GRASS                    186.0                218.0                   9
# GRASS                    197.0                236.0                   9
# GRASS                    208.0                240.0                   9
# GRASS                    223.0                185.0                   9
#
#            SHORT-LINE-DENSITY-5  SHORT-LINE-DENSITY-2  VEDGE-MEAN  VEDGE-SD  \
# ...

# %%
dados_item3 = dados.loc['FOLIAGE'];
dados_item3 = dados_item3.iloc[0:5];
display(dados_item3);
# Out:
#          REGION-CENTROID-COL  REGION-CENTROID-ROW  REGION-PIXEL-COUNT  \
# FOLIAGE                101.0                121.0                   9
# FOLIAGE                 21.0                122.0                   9
# FOLIAGE                 45.0                 89.0                   9
# FOLIAGE                 18.0                 87.0                   9
# FOLIAGE                 52.0                102.0                   9
#
#          SHORT-LINE-DENSITY-5  SHORT-LINE-DENSITY-2  VEDGE-MEAN  VEDGE-SD  \
# FOLIAGE              0.111111                   0.0    0.666667  0.843274
# FOLIAGE              0.000000                   0.0    0.444444  0.403687
# FOLIAGE              0.000000                   0.0    0.777778  0.340741
# FOLIAGE              0.000000                   0.0    1.555556  1.962613
# FOLIAGE              0.000000                   0.0    0.722222  0.507407
#
#          HEDGE-MEAN  HEDGE-SD  INTENSITY-MEAN  RAWRED-MEAN  RAWBLUE-MEAN  \
# ...

# %%
colunas_item3 = dados.loc['FOLIAGE'];
colunas_item3 = colunas_item3.iloc[0:0];
display(colunas_item3);
# Out:
# Empty DataFrame
# Columns: [REGION-CENTROID-COL, REGION-CENTROID-ROW, REGION-PIXEL-COUNT, SHORT-LINE-DENSITY-5, SHORT-LINE-DENSITY-2, VEDGE-MEAN, VEDGE-SD, HEDGE-MEAN, HEDGE-SD, INTENSITY-MEAN, RAWRED-MEAN, RAWBLUE-MEAN, RAWGREEN-MEAN, EXRED-MEAN, EXBLUE-MEAN, EXGREEN-MEAN, VALUE-MEAN, SATURATION-MEAN, HUE-MEAN]
# Index: []

# %%
tipos_item3 = dados.loc['FOLIAGE'];
tipos_item3 = tipos_item3.info();
display(tipos_item3);
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 30 entries, FOLIAGE to FOLIAGE
# Data columns (total 19 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   REGION-CENTROID-COL   30 non-null     float64
#  1   REGION-CENTROID-ROW   30 non-null     float64
#  2   REGION-PIXEL-COUNT    30 non-null     int64
#  3   SHORT-LINE-DENSITY-5  30 non-null     float64
#  4   SHORT-LINE-DENSITY-2  30 non-null     float64
#  5   VEDGE-MEAN            30 non-null     float64
#  6   VEDGE-SD              30 non-null     float64
#  7   HEDGE-MEAN            30 non-null     float64
#  8   HEDGE-SD              30 non-null     float64
#  9   INTENSITY-MEAN        30 non-null     float64
#  10  RAWRED-MEAN           30 non-null     float64
#  11  RAWBLUE-MEAN          30 non-null     float64
#  12  RAWGREEN-MEAN         30 non-null     float64
#  13  EXRED-MEAN            30 non-null     float64
# ...

# %%
describe_item3 = dados.loc['FOLIAGE'];
describe_item3 = describe_item3.describe();
display(describe_item3);
# Out:
#        REGION-CENTROID-COL  REGION-CENTROID-ROW  REGION-PIXEL-COUNT  \
# count            30.000000             30.00000                30.0
# mean             76.500000            111.40000                 9.0
# std              63.572793             21.46304                 0.0
# min               1.000000             75.00000                 9.0
# 25%              37.250000             90.25000                 9.0
# 50%              59.000000            115.00000                 9.0
# 75%              99.250000            125.00000                 9.0
# max             231.000000            145.00000                 9.0
#
#        SHORT-LINE-DENSITY-5  SHORT-LINE-DENSITY-2  VEDGE-MEAN    VEDGE-SD  \
# count             30.000000             30.000000   30.000000   30.000000
# mean               0.003704              0.014815    3.827778   30.905793
# std                0.020286              0.038416    6.696062  113.297318
# ...

# %%
dataframe_not_NA = dados.dropna();
display(dataframe_not_NA);
# Out:
#            REGION-CENTROID-COL  REGION-CENTROID-ROW  REGION-PIXEL-COUNT  \
# BRICKFACE                140.0                125.0                   9
# BRICKFACE                188.0                133.0                   9
# BRICKFACE                105.0                139.0                   9
# BRICKFACE                 34.0                137.0                   9
# BRICKFACE                 39.0                111.0                   9
# ...                        ...                  ...                 ...
# GRASS                     36.0                243.0                   9
# GRASS                    186.0                218.0                   9
# GRASS                    197.0                236.0                   9
# GRASS                    208.0                240.0                   9
# GRASS                    223.0                185.0                   9
#
#            SHORT-LINE-DENSITY-5  SHORT-LINE-DENSITY-2  VEDGE-MEAN  VEDGE-SD  \
# ...

# %%
teste = dados
teste.plot(kind='bar', x='index', y='HEDGE-MEAN');
plt.show;
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.7/dist-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3360             try:
# -> 3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
#
# /usr/local/lib/python3.7/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# /usr/local/lib/python3.7/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'index'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ...
